# %%
with open('Wishlist_Selection.html', 'r', encoding='utf-8') as f:
    content = f.read()

new_content = content.replace('additional places want to go/', 'additional%20places%20want%20to%20go/')

with open('Wishlist_Selection.html', 'w', encoding='utf-8') as f:
    f.write(new_content)

print('Fixed')
